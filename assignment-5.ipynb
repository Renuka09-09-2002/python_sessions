# %%
#Guess a number is a game that prompts a player to guess a number between 0 and 9, which
#is randomly generated by the system. When the input given by the user matches the
#number generated by the system then the user wins. The game should go as follows:

#Guess the number: 5
#Sorry, try again
#Guess the number: 3
#Sorry, try again
#Guess the number: 8
#You got it right! Congo!

import random
def number():
    secret_number = random.randint(0, 9)
    print(secret_number)
    while True:
        guess = eval(input("Guess the number (between 0 and 9): "))
        if guess == secret_number:
            print("You got it right! Congratulations!")
            break
        else:
            print("Sorry, try again.")
number()
# Out:
# 8
# Guess the number (between 0 and 9): 1
# Sorry, try again.
# Guess the number (between 0 and 9): 2
# Sorry, try again.
# Guess the number (between 0 and 9): 4
# Sorry, try again.
# Guess the number (between 0 and 9): 6
# Sorry, try again.
# Guess the number (between 0 and 9): 3
# Sorry, try again.
# Guess the number (between 0 and 9): 8
# You got it right! Congratulations!

# %%
#Make an improvement to the Guess a number game. Guide the user where they are
#standing and limit the number of attempts to 3. For example, the game should go like this:

#Guess the number: 4
#Too low
#Guess the number: 9
#Too high
#Guess the number: 5
#Sorry you Lost!#



import random
def number():
    secret_number = random.randint(0, 9)
    print(secret_number)
    max_attempts = 3
    attempts=0
    while attempts < max_attempts:
        
        guess = eval(input("Guess the number (between 0 and 9): "))
        if guess == secret_number:
            print("Congratulations! You guessed it right!")
            break
        elif guess < secret_number:
            print("Too low. Try again.")
        else:
            print("Too high. Try again.")
        attempts+=1
    if attempts == max_attempts:
            print("Sorry, you lost!")
        
number()
# Out:
# 5
# Guess the number (between 0 and 9): 1
# Too low. Try again.
# Guess the number (between 0 and 9): 2
# Too low. Try again.
# Guess the number (between 0 and 9): 3
# Too low. Try again.
# Sorry, you lost!

# %% [markdown]
# ##

# %%
#Let us make the above game a little more interesting by converting it into a gambling
#problem. Suppose that a player starts with Rs. 1,000. If a player can guess the number in his
#first chance, then he will be given a prize of Rs. 5,000, if he requires 2 attempts then he will
#get a prize of Rs.1,000. If he loses then he will lose Rs. 500. For example the game should go
#like this:

#You have a cash of Rs. 1,000 with you...
#Guess the number: 8
#Too high
#Guess the number: 3
#You have just won Rs. 1,000
#Your balance: Rs. 2000


import random

def number():
    balance = 1000
    print("You have a cash of Rs. 1,000 with you...")
    secret_number = random.randint(0, 9)
    max_attempts = 3
    attempts = 0
    print(secret_number)
    while attempts < max_attempts:
        guess = eval(input("Guess the number (between 0 and 9): "))
        if guess == secret_number:
            if attempts == 0:
                prize = 5000
            elif attempts == 1:
                prize = 1000
            else:
                prize = 0
            
            print("{} is u won".format(prize))
            balance += prize
            break
        elif guess < secret_number:
            print("Too low. Try again.")
        else:
            print("Too high. Try again.")
        
        attempts += 1
    
   
    if attempts == max_attempts:
        print("Sorry, you lost! You lose Rs. 500.")
        balance -= 500
    
   
    print("{} is u r balance".format(balance))
number()
# Out:
# You have a cash of Rs. 1,000 with you...
# 2
# Guess the number (between 0 and 9): 1
# Too low. Try again.
# Guess the number (between 0 and 9): 3
# Too high. Try again.
# Guess the number (between 0 and 9): 2
# 0 is u won
# 1000 is u r balance

# %%
#Suppose that a player wants to play a game which requires him Rs. 1,000 to start. If the
#current balance in his account is less than Rs. 1,000 he needs to withdraw the extra money
#from his e-wallet.

#Note that if the sum of money in his courrent account and the amount withdrawn is greater than
#or equal to Rs. 1,000 then he can start playing the game. However if the sum is less than Rs.
#1,000 then the program should keep displaying the user the message “You still do not have
#enough money to start playing.” and keep prompting the user to withdraw money unless it
#crosses Rs. 1,000. Once ready, i.e. if his current account balance crosses Rs. 1,000, it will display
#a message “Now, you are ready to play the game.” Your program should also display the account
#balance and the current amount in the e-wallet.

#(consider: initial account balance is Rs. 200 and money in the e-wallet is Rs. 5,000)

#(Do further improvement by checking if the e-wallet balance becomes NIL, etc.)


initial_account=200
e_wallet=5000
print("the current balance in my account is {}".format(initial_account))
while initial_account<1000:
    print("you dont have enough money")
    withdraw=eval(input("enter the amount : "))
    initial_account=initial_account+withdraw
    print("initial account is :",initial_account)
    if initial_account>=1000:
        print("u can start playing !")
        print("ur initial account is {} and ur wallet balance is {}".format(initial_account,e_wallet,withdraw))
# Out:
# the current balance in my account is 200
# you dont have enough money
# enter the amount : 400
# initial account is : 600
# you dont have enough money
# enter the amount : 3457
# initial account is : 4057
# u can start playing !
# ur initial account is 4057 and ur wallet balance is 5000
